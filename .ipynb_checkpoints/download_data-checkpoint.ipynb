# %%
import tushare as ts
import pandas as pd
import datetime, time
import sqlite3

# %%
from IndexDailybasic import IndexDailybasic
inde_daily_basic = IndexDailybasic()
ts_code, start_date, end_date = '000001.SH', '20040101', '20230325'
df = inde_daily_basic.read_data(ts_code, start_date, end_date)

# %%
df
# Out:
#                     0
# 0   000001.SH20040102
# 1           000001.SH
# 2            20040102
# 3     3295001954556.0
# 4      794485057722.0
# 5      453941610705.0
# 6      107781268279.0
# 7      103266916406.0
# 8                1.52
# 9                1.59
# 10              45.34
# 11              37.11
# 12               2.77
