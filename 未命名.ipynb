# %%
import tushare as ts
import pandas as pd
import datetime, time
import sqlite3
import sqlite_data
import time

# %%
pro = ts.pro_api()

# %%
df = pro.fx_obasic()

# %%
df
# Out:
#         ts_code     name classify exchange  min_unit  max_unit      pip  \
# 0   AUDCAD.FXCM     澳元加元       FX     FXCM       1.0       NaN  0.00001
# 1   AUDCHF.FXCM   澳元瑞士法郎       FX     FXCM       1.0       NaN  0.00001
# 2   AUDJPY.FXCM     澳元日元       FX     FXCM       1.0       NaN  0.00001
# 3   AUDNZD.FXCM   澳元新西兰元       FX     FXCM       1.0       NaN  0.00001
# 4   AUDUSD.FXCM     澳元美元       FX     FXCM       1.0       NaN  0.00001
# ..          ...      ...      ...      ...       ...       ...      ...
# 64  BTCUSD.FXCM    比特币美元   CRYPTO     FXCM       1.0     500.0  1.00000
# 65  BCHUSD.FXCM  比特币现金美元   CRYPTO     FXCM       1.0    1000.0  1.00000
# 66  ETHUSD.FXCM    以太币美元   CRYPTO     FXCM       1.0    1000.0  1.00000
# 67  LTCUSD.FXCM    莱特币美元   CRYPTO     FXCM       1.0    1000.0  0.01000
# 68  XRPUSD.FXCM    瑞波币美元   CRYPTO     FXCM     100.0    1000.0  0.01000
#
#     pip_cost  traget_spread  min_stop_distance           trading_hours  \
# ...

# %%
sqlite_data.write(df,'fx_obasic')
