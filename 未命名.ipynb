# %%
import tushare as ts
import pandas as pd
import datetime, time
import sqlite3
import sqlite_data

# %%
pro = ts.pro_api()
df = pro.namechange()

# %%
df.head(3)
# Out:
#      ts_code  name start_date end_date ann_date change_reason
# 0  601061.SH  中信金属   20230410     None     None            其他
# 1  603135.SH  中重科技   20230410     None     None            其他
# 2  603125.SH  常青科技   20230410     None     None            其他

# %%
sqlite_data.write(df, 'namechange')
