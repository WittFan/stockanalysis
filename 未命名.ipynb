# %%
import tushare as ts
import pandas as pd
import datetime, time
import sqlite3
import sqlite_data
import time

# %%
pro = ts.pro_api()

# %%
#获取单个公司高管全部数据
df = pro.stk_rewards(ts_code='000001.SZ')

# %%
df = pro.trade_cal()
df['exchange_cal_date'] = df.apply(lambda x: x['exchange'] + str(x['cal_date']), axis=1)
print(df)
# Out:
#       exchange  cal_date  is_open pretrade_date exchange_cal_date
# 0          SSE  20231231        0      20231229       SSE20231231
# 1          SSE  20231230        0      20231229       SSE20231230
# 2          SSE  20231229        1      20231228       SSE20231229
# 3          SSE  20231228        1      20231227       SSE20231228
# 4          SSE  20231227        1      20231226       SSE20231227
# ...        ...       ...      ...           ...               ...
# 12061      SSE  19901223        0      19901221       SSE19901223
# 12062      SSE  19901222        0      19901221       SSE19901222
# 12063      SSE  19901221        1      19901220       SSE19901221
# 12064      SSE  19901220        1      19901219       SSE19901220
# 12065      SSE  19901219        1          None       SSE19901219
#
# [12066 rows x 5 columns]

# %%
sqlite_data.write(df, 'trade_cal')

# %%
from sqlite_data import DataApi
data_api = DataApi()

# %%
data_api.trade_cal()['cal_date'].unique()
# Out:
# array(['20231231', '20231230', '20231229', ..., '19901014', '19901013',
#        '19901012'], dtype=object)

# %%
sqlite_data.write(df,'fx_obasic')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/qf/5gtxhjw15mn2v3l7mc3qv_br0000gn/T/ipykernel_5023/1259668682.py in <module>
# ----> 1 sqlite_data.write(df,'fx_obasic')
#
# ~/stockanalysis/sqlite_data.py in write(dataframe, table_name)
#      11     """
#      12     conn = sqlite3.connect('data.db')
# ---> 13     dataframe.to_sql(table_name, conn, if_exists='append', index=False)
#      14     conn.close()
#      15
#
# ~/anaconda3/envs/quant/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~/anaconda3/envs/quant/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~/anaconda3/envs/quant/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2224         )
#    2225         table.create()
# -> 2226         table.insert(chunksize, method)
#    2227
#    2228     def has_table(self, name: str, schema: str | None = None):
#
# ~/anaconda3/envs/quant/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/anaconda3/envs/quant/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#    1922     def _execute_insert(self, conn, keys, data_iter):
#    1923         data_list = list(data_iter)
# -> 1924         conn.executemany(self.insert_statement(num_rows=1), data_list)
#    1925
#    1926     def _execute_insert_multi(self, conn, keys, data_iter):
#
# OperationalError: table fx_obasic has no column named ann_date
